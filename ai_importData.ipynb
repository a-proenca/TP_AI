# %% [markdown]
# #### Script to import necessary data to postgres database
# ##### MEI 2022/2023

# %%
import sys
# !{sys.executable} -m pip install pysftp
# !{sys.executable} -m pip install gpxpy
# !{sys.executable} -m pip install sqlalchemy-databricks
# !{sys.executable} -m pip install psycopg2
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install os.path2

import sys
import pandas as pd
import csv
import geopandas as gpd
import ipywidgets as widgets
from IPython.display import display
import pysftp
from zipfile import ZipFile
import glob
import gpxpy
from datetime import datetime
import sys
import psycopg2
#import psycopg
import os
import getpass
import subprocess

#!{sys.executable} -m pip install "psycopg[binary]"

# %% [markdown]
# #### Connect to existing postgres database
# If this database doesn't exist, it will be created

# %%
conn = 0
cursor = 0


def create_postgres_database():
    global conn
    global cursor
    # Get the database connection options
    host = input("Enter the  PostgreSQL host connection: ")
    port = input("Enter the PostgreSQL port connection: ")
    username = input("Enter the PostgreSQL username connection: ")
    password = input("Enter the PostgreSQL password connection: ")
    db_name = input("Enter the PostgreSQL database: ")

    # Connect to the default PostgreSQL database
    conn = psycopg2.connect(
        host=host,
        port=port,
        user=username,
        password=password,
        database="postgres"
    )

    try:
        # Create a new cursor object
        conn.autocommit = True
        cursor = conn.cursor()

        # Check if the database already exists
        cursor.execute("SELECT 1 FROM pg_catalog.pg_database WHERE datname = %s;", (db_name,))
        exists = cursor.fetchone()

        if exists:
            print(f"Database '{db_name}' already exists.")
        else:
            # Create the new database with the user-provided name
            cursor.execute(f"CREATE DATABASE {db_name};")
            print(f"Database '{db_name}' created successfully!")

        # Commit the transaction
        conn.commit()
    except psycopg2.Error as e:
        print("Error creating or checking PostgreSQL database:", e)
    finally:
        # Close the cursor and the connection
        cursor.close()
        conn.close()

        conn = psycopg2.connect(
            host=host,
            port=port,
            user=username,
            password=password,
            database=db_name
        )
        if conn:
            conn.autocommit = True
            cursor = conn.cursor()
            print("Connected to PostgreSQL database")

# %%
create_postgres_database()

# %% [markdown]
# #### Import SenseMyCity & Wikiloc data

# %%
# Function to create the recolhas table if it doesn't exist

def create_recolhas_table():
    try:
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS recolhas (
            id  SERIAL PRIMARY KEY,
                id_recolha VARCHAR(255),
                atividade VARCHAR(255),
                id_user VARCHAR(255),
                instante VARCHAR(255),
                latitude FLOAT,
                longitude FLOAT,
                posicao VARCHAR(255),
                modo_transporte VARCHAR(255)
            )
        ''')

        conn.commit()
        print("Table created successfully")
    except Exception as e:
        print("Error occurred during query execution:", e)

# %%
create_recolhas_table()

# %%
#Connecting to the SFTP server and downloading sessions
#Using the pysftp package: https://www.ittsystems.com/how-to-access-sftp-server-in-python/ e https://pysftp.readthedocs.io/en/release_0.2.9/index.html

def connect_to_server():
    dir_src = 'sessions'
    if not os.path.exists(dir_src):
        os.makedirs(dir_src)

   # hostname = input("SFTP server:") #urbysense.dei.uc.pt/
   # username = input("username:") # amistudent
   # password = getpass.getpass("password:") # ami_mei_2023

    hostname = "urbysense.dei.uc.pt"
    username = "amistudent"
    password = "ami_mei_2023"

    with pysftp.Connection(host=hostname, username=username, password=password) as sftp:
        print("Connection successfully established ... ")
        # Switch to a remote directory - change if it is different
        sftp.cwd('data/profile2')

        # Obtain structure of the remote directory 'data/profile2'
        directory_structure = sftp.listdir_attr()

        # Print data
        for attr in directory_structure:
            print(attr.filename, attr)

        #Downloading sessions
        sftp.get_d('.', dir_src, preserve_mtime=True)

# %%
connect_to_server()

# %%
#Function to convert from Hexadecimal Accelerometer data list of values to a Decimal average

def from_hex_to_avg(compressedArray):
    count = 0
    total = 0.0
    for i in range(len(compressedArray) - 3):
        if i % 4 == 0:
            reading = compressedArray[i:i + 4]
            value = int(reading, base=16)
            if value > 128 * 256:
                value = value - 65536
            valuef = value / 256.0
            total += valuef
            count += 1
            print(reading, int(reading, base=16), valuef, total, count)
    return total / count

# %%
from_hex_to_avg(
"001600390031ff78febefe99fef0ff63000f0057001cff51fe5efea1ffd200a900a5ffd4fee4fed7ff91007d00f300c50041ff9cff46ff85fffe0018fffeff47fecbfecafec3fe81fe36fe61fe4cfe2ffeecff57ffb40006003b002b008a00a20049ff6d")

# %%
#Unziping when it is needed - SenseMyCity Session
dir_src = 'sessions'
if not os.path.exists(dir_src):
    os.makedirs(dir_src)


# hostname = input("SFTP server:") #urbysense.dei.uc.pt/
# username = input("username:") # amistudent
# password = getpass.getpass("password:") # ami_mei_2023

hostname = "urbysense.dei.uc.pt"
username = "amistudent"
password = "ami_mei_2023"

with pysftp.Connection(host=hostname, username=username, password=password) as sftp:
    print("Connection successfully established ... ")
    # Switch to a remote directory - change if it is different
    sftp.cwd('data/profile2')

    # Obtain structure of the remote directory 'data/profile2'
    directory_structure = sftp.listdir_attr()

    # Print data
    for attr in directory_structure:
        print(attr.filename, attr)

    #Downloading sessions
    sftp.get_d('.', dir_src, preserve_mtime=True)

filenames = os.listdir(dir_src)

if not os.path.exists(dir_src + "_processed"):
    os.makedirs(dir_src + "_processed")

dir_separator = '/'
if sys.platform.startswith('win'):
    dir_separator = '\\'

for file in filenames:
    print(file)
    if os.path.isfile(dir_src + dir_separator + file):
        with open(dir_src + dir_separator + file) as current_file:
            if file.endswith(".zip"):

                tokens = file.split("_")
                session = tokens[1]
                user_id = tokens[2]
                transport = tokens[3]
                activity = '-'.join(tokens[4:]).split(".")[0]

                gps_file = glob.glob("./**/SenseMyCity-" + session + "-gps.csv", recursive=True)
                if len(gps_file) == 0:
                    with ZipFile(dir_src + dir_separator + file, 'r') as zip_ref:
                        zip_ref.extractall(path='SenseMyCity')
                        gps_file = glob.glob("./**/SenseMyCity-" + session + "-gps.csv", recursive=True)

                #Accelerometer sensor as it is (in Hexadecimal values) - do the same for other sensor you want
                #acc_file = glob.glob("./**/SenseMyCity-"+session+"-accelerometer.csv", recursive = True)
                #if len(acc_file) == 0:
                #   with ZipFile( dir_src + "/" + file, 'r') as zip_ref:
                #      zip_ref.extractall()

                recolhas_list = []
                #recolhas_list_acc = []
                #if len(gps_file) > 0 and len(acc_file) > 0 :
                if len(gps_file) > 0:
                    print(gps_file[0])
                    basename = gps_file[0].split(dir_separator)
                    basename_file = basename[len(basename) - 1]
                    #basename = acc_file[0].split("/")
                    #basename_file_acc = basename[len(basename) - 1]

                    if not os.path.exists(dir_src + "_processed" + dir_separator + basename_file.split(".")[0]):
                        print(basename_file)
                        with open(dir_src + "_processed" + dir_separator + basename_file.split(".")[0],
                                  "w") as flag_file:
                            flag_file.write("inserted " + str(len(recolhas_list)) + " points")

                        with open(gps_file[0]) as current_csv_file:
                            for line in current_csv_file:
                                values = line.split(";")
                                if len(values) > 9 and values[0].isnumeric():
                                    recolhas_list.append((values[3], values[7], values[8], values[6]))

                        if len(recolhas_list) > 0:
                            # insert multiple points into the recolhas table
                            sql = "INSERT INTO recolhas(id_recolha, atividade, id_user, instante, latitude, longitude, posicao, modo_transporte) VALUES (" + session + ",'" + activity + "'," + user_id + ",%s,%s,%s,%s,'" + transport + "')"
                            try:
                                # execute the INSERT statements
                                cursor.executemany(sql, recolhas_list)
                                # commit the changes to the database
                                conn.commit()
                            except (Exception, psycopg2.DatabaseError) as error:
                                print(error)

                        #If Accelerometer is also considered in SMC sessions
                        """ with open(acc_file[0]) as current_csv_file:
                            for line in current_csv_file:
                                values = line.split(";")
                                if len(values) > 4 and values[0].isnumeric():
                                    #print(values[2][3:],values[3][3:],values[4][3:])
                                    recolhas_list_acc.append((values[1],str(fromHexToAvg(values[2][3:])),str(fromHexToAvg(values[3][3:])),str(fromHexToAvg(values[4][3:]))))
                                    #print(recolhas_list_acc[len(recolhas_list_acc)-1])
                        if len(recolhas_list_acc) > 0:


                            # insert multiple points into the recolhas_acc table
                            sql = "INSERT INTO recolhas_acc(id_recolha, instante, accx_avg, accy_avg, accz_avg) VALUES (" + session + ",%s,%s,%s,%s)"
                            conn = None
                             try:
                                # execute the INSERT statements
                                cursor.executemany(sql,recolhas_list_acc)
                                # commit the changes to the database
                                conn.commit()
                            except (Exception, psycopg2.DatabaseError) as error:
                                print(error) """


            elif file.endswith(".gpx"):  #Wikiloc session - please see https://pypi.org/project/gpxpy/
                if not os.path.exists(dir_src + "_processed" + dir_separator + file.split(".")[0]):
                    recolhas_list = []
                    with open(dir_src + "_processed" + dir_separator + file.split(".")[0], "w") as flag_file:
                        flag_file.write("inserted " + str(len(recolhas_list)) + " points")
                    with open(dir_src + dir_separator + file) as gpx_file:
                        tokens = file.split("_")
                        session = tokens[1]
                        user_id = tokens[2]
                        transport = tokens[3]
                        activity = '-'.join(tokens[4:]).split(".")[0]
                        gpx = gpxpy.parse(gpx_file)
                        for track in gpx.tracks:
                            for segment in track.segments:
                                for point in segment.points:
                                    recolhas_list.append((point.time.timestamp(), point.latitude, point.longitude,
                                                          point.longitude, point.latitude))

                        if len(recolhas_list) > 0:
                            # insert multiple points into the recolhas table

                            sql = "INSERT INTO recolhas(id_recolha, atividade, id_user, instante, latitude, longitude, posicao, modo_transporte) VALUES (" + session + ",'" + activity + "'," + user_id + ",%s,%s,%s,ST_SetSRID(ST_MakePoint(%s, %s), 4326),'" + transport + "')"
                            try:
                                # execute the INSERT statements
                                cursor.executemany(sql, recolhas_list)
                                # commit the changes to the database
                                conn.commit()
                            except (Exception, psycopg2.DatabaseError) as error:
                                print(error)
# Out:
# Connection successfully established ...
# sensemycity_46166_999_BIKE_HEALTH.zip -rw-r--r--   1 1019     1019       423223 22 Mar 22:53 sensemycity_46166_999_BIKE_HEALTH.zip
# sensemycity_46184_596_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019      1025497 27 Mar 22:25 sensemycity_46184_596_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46197_993_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019        81785 29 Mar 22:47 sensemycity_46197_993_WALK_EDUCATION.zip
# sensemycity_46200_773_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019      1001805 19 Apr 22:13 sensemycity_46200_773_CAR_EDUCATION.zip
# sensemycity_46201_111_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019       227163 03 Apr 20:57 sensemycity_46201_111_WALK_EDUCATION.zip
# sensemycity_46211_993_CAR_ SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019        58100 05 Apr 20:25 sensemycity_46211_993_CAR_ SHOPPING_ERRANDS.zip
# sensemycity_46212_993_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019        24474 05 Apr 20:25 sensemycity_46212_993_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46213_993_WALK_HEALTH.zip -rw-rw-r--   1 1019     1019        58163 05 Apr 20:25 sensemycity_46213_993_WALK_HEALTH.zip
# sensemycity_46214_999_BIKE_HEALTH.zip -rw-r--r--   1 1019     1019       264270 19 Apr 12:09 sensemycity_46214_999_BIKE_HEALTH.zip
# sensemycity_46218_773_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019      1083072 19 Apr 22:13 sensemycity_46218_773_CAR_LEISURE.zip
# sensemycity_46219_259_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       224840 15 Apr 17:01 sensemycity_46219_259_CAR_LEISURE.zip
# sensemycity_46221_999_CAR_SHOPPING_ERRANDS.zip -rw-r--r--   1 1019     1019       106540 19 Apr 12:09 sensemycity_46221_999_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46230_259_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       217945 16 Apr 13:47 sensemycity_46230_259_CAR_LEISURE.zip
# sensemycity_46231_259_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       412842 16 Apr 13:47 sensemycity_46231_259_CAR_LEISURE.zip
# sensemycity_46234_259_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       233895 16 Apr 22:44 sensemycity_46234_259_CAR_LEISURE.zip
# sensemycity_46235_259_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       285151 16 Apr 22:44 sensemycity_46235_259_CAR_LEISURE.zip
# sensemycity_46239_773_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       523725 19 Apr 22:13 sensemycity_46239_773_CAR_LEISURE.zip
# sensemycity_46249_773_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       519789 19 Apr 22:13 sensemycity_46249_773_CAR_LEISURE.zip
# sensemycity_46253_259_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019        53538 19 Apr 22:56 sensemycity_46253_259_WALK_EDUCATION.zip
# sensemycity_46259_993_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       188565 24 Apr 10:39 sensemycity_46259_993_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46260_993_CAR_OTHER.zip -rw-rw-r--   1 1019     1019       842127 24 Apr 10:39 sensemycity_46260_993_CAR_OTHER.zip
# sensemycity_46263_999_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       152777 08 May 16:39 sensemycity_46263_999_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46264_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       218090 23 Apr 18:12 sensemycity_46264_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46273_993_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019      1008216 24 Apr 10:39 sensemycity_46273_993_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46286_999_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019        82236 08 May 15:52 sensemycity_46286_999_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46300_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       222049 25 Apr 19:05 sensemycity_46300_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46301_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       245490 25 Apr 19:05 sensemycity_46301_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46310_999_CAR_HEALTH.zip -rw-rw-r--   1 1019     1019       303008 08 May 15:47 sensemycity_46310_999_CAR_HEALTH.zip
# sensemycity_46312_999_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019        96662 08 May 15:35 sensemycity_46312_999_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46323_999_BIKE_HEALTH.zip -rw-rw-r--   1 1019     1019       373526 08 May 15:35 sensemycity_46323_999_BIKE_HEALTH.zip
# sensemycity_46325_999_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       339171 08 May 15:09 sensemycity_46325_999_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46326_259_PUBLICTRANSIT_OTHER.zip -rw-rw-r--   1 1019     1019       574175 04 May 21:13 sensemycity_46326_259_PUBLICTRANSIT_OTHER.zip
# sensemycity_46328_259_PUBLICTRANSIT_OTHER.zip -rw-rw-r--   1 1019     1019       183444 04 May 21:17 sensemycity_46328_259_PUBLICTRANSIT_OTHER.zip
# sensemycity_46333_999_WALK_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       292331 08 May 12:06 sensemycity_46333_999_WALK_SHOPPING_ERRANDS.zip
# sensemycity_46349_515_WALK_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       232962 28 May 16:27 sensemycity_46349_515_WALK_SHOPPING_ERRANDS.zip
# sensemycity_46350_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       267389 12 May 11:04 sensemycity_46350_259_CAR_EDUCATION.zip
# sensemycity_46352_515_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019       302443 28 May 16:31 sensemycity_46352_515_WALK_EDUCATION.zip
# sensemycity_46361_515_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019       294783 28 May 16:29 sensemycity_46361_515_WALK_EDUCATION.zip
# sensemycity_46376_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       380511 17 May 19:59 sensemycity_46376_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46380_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       324797 17 May 19:59 sensemycity_46380_259_CAR_EDUCATION.zip
# sensemycity_46389_259_PUBLICTRANSIT_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       471881 19 May 19:00 sensemycity_46389_259_PUBLICTRANSIT_SHOPPING_ERRANDS.zip
# sensemycity_46392_259_PUBLICTRANSIT_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       388126 19 May 19:00 sensemycity_46392_259_PUBLICTRANSIT_SHOPPING_ERRANDS.zip
# sensemycity_46393_259_PUBLICTRANSIT_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       700418 19 May 19:00 sensemycity_46393_259_PUBLICTRANSIT_SHOPPING_ERRANDS.zip
# sensemycity_46394_993_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019       200233 29 May 16:01 sensemycity_46394_993_WALK_EDUCATION.zip
# sensemycity_46398_515_WALK_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       240196 28 May 16:23 sensemycity_46398_515_WALK_SHOPPING_ERRANDS.zip
# sensemycity_46399_993_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       955430 29 May 16:01 sensemycity_46399_993_CAR_EDUCATION.zip
# sensemycity_46400_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       329205 29 May 22:05 sensemycity_46400_259_CAR_EDUCATION.zip
# sensemycity_46401_515_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019        90229 30 May 11:23 sensemycity_46401_515_CAR_EDUCATION.zip
# sensemycity_46402_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       266861 29 May 22:05 sensemycity_46402_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46403_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       182990 29 May 22:05 sensemycity_46403_259_CAR_EDUCATION.zip
# sensemycity_46407_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       268675 30 May 20:20 sensemycity_46407_259_CAR_EDUCATION.zip
# sensemycity_46412_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       307791 01 Jun 10:46 sensemycity_46412_259_CAR_EDUCATION.zip
# sensemycity_46422_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       254180 01 Jun 10:46 sensemycity_46422_259_CAR_EDUCATION.zip
# sensemycity_46435_182_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019      1330251 03 Jun 12:42 sensemycity_46435_182_WALK_EDUCATION.zip
# sensemycity_46436_384_OTHER_LEISURE.zip -rw-rw-r--   1 1019     1019       440805 05 Jun 22:27 sensemycity_46436_384_OTHER_LEISURE.zip
# sensemycity_46437_384_OTHER_LEISURE.zip -rw-rw-r--   1 1019     1019       137893 05 Jun 22:27 sensemycity_46437_384_OTHER_LEISURE.zip
# sensemycity_46442_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       298780 05 Jun 15:40 sensemycity_46442_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46447_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       245501 05 Jun 15:40 sensemycity_46447_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46449_259_CAR_SHOPPING_ERRANDS.zip -rw-rw-r--   1 1019     1019       225234 05 Jun 15:40 sensemycity_46449_259_CAR_SHOPPING_ERRANDS.zip
# sensemycity_46453_182_PUBLICTRANSIT_OTHER.zip -rw-rw-r--   1 1019     1019      1030174 07 Jun 21:51 sensemycity_46453_182_PUBLICTRANSIT_OTHER.zip
# sensemycity_46454_182_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019      1289660 07 Jun 21:51 sensemycity_46454_182_WALK_EDUCATION.zip
# sensemycity_46462_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       245860 07 Jun 19:47 sensemycity_46462_259_CAR_EDUCATION.zip
# sensemycity_46463_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       235143 08 Jun 15:40 sensemycity_46463_259_CAR_EDUCATION.zip
# sensemycity_46464_182_PUBLICTRANSIT_OTHER.zip -rw-rw-r--   1 1019     1019      1056578 14 Jun 21:04 sensemycity_46464_182_PUBLICTRANSIT_OTHER.zip
# sensemycity_46465_182_WALK_EDUCATION.zip -rw-rw-r--   1 1019     1019      1318564 14 Jun 21:04 sensemycity_46465_182_WALK_EDUCATION.zip
# sensemycity_46466_259_CAR_SHOPPING.zip -rw-rw-r--   1 1019     1019       273603 09 Jun 15:25 sensemycity_46466_259_CAR_SHOPPING.zip
# sensemycity_46467_259_CAR_SHOPPING.zip -rw-rw-r--   1 1019     1019       264880 09 Jun 15:25 sensemycity_46467_259_CAR_SHOPPING.zip
# sensemycity_46468_259_CAR_LEISURE.zip -rw-rw-r--   1 1019     1019       527036 12 Jun 10:52 sensemycity_46468_259_CAR_LEISURE.zip
# sensemycity_46471_259_CAR_EDUCATION.zip -rw-rw-r--   1 1019     1019       237175 13 Jun 10:18 sensemycity_46471_259_CAR_EDUCATION.zip
# wikiloc_2599_259_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019        95598 12 Jun 10:52 wikiloc_2599_259_WALK_HEALTH.gpx
# wikiloc_31201_312_CAR_LEISURE.gpx -rw-rw-r--   1 1019     1019        49735 16 Jun 22:32 wikiloc_31201_312_CAR_LEISURE.gpx
# wikiloc_31202_312_CAR_HEALTH.gpx -rw-rw-r--   1 1019     1019        45654 16 Jun 22:32 wikiloc_31202_312_CAR_HEALTH.gpx
# wikiloc_31203_312_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        19984 16 Jun 22:32 wikiloc_31203_312_CAR_EDUCATION.gpx
# wikiloc_31204_312_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        80997 16 Jun 22:32 wikiloc_31204_312_CAR_OTHER.gpx
# wikiloc_31205_312_WALK_EDUCATION.gpx -rw-rw-r--   1 1019     1019        36629 16 Jun 22:32 wikiloc_31205_312_WALK_EDUCATION.gpx
# wikiloc_31206_312_CAR_HEALTH.gpx -rw-rw-r--   1 1019     1019        34173 16 Jun 22:32 wikiloc_31206_312_CAR_HEALTH.gpx
# wikiloc_31207_312_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        17145 16 Jun 22:32 wikiloc_31207_312_CAR_EDUCATION.gpx
# wikiloc_31208_312_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019       121593 16 Jun 22:32 wikiloc_31208_312_CAR_OTHER.gpx
# wikiloc_35601_356_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        33579 08 Jun 18:35 wikiloc_35601_356_CAR_EDUCATION.gpx
# wikiloc_35602_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        52579 08 Jun 18:35 wikiloc_35602_356_CAR_OTHER.gpx
# wikiloc_35603_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        56081 08 Jun 18:35 wikiloc_35603_356_CAR_OTHER.gpx
# wikiloc_35604_356_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        37476 08 Jun 18:35 wikiloc_35604_356_CAR_EDUCATION.gpx
# wikiloc_35605_356_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        27387 08 Jun 18:35 wikiloc_35605_356_CAR_EDUCATION.gpx
# wikiloc_35606_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        55860 08 Jun 18:35 wikiloc_35606_356_CAR_OTHER.gpx
# wikiloc_35607_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        43667 08 Jun 18:35 wikiloc_35607_356_CAR_OTHER.gpx
# wikiloc_35608_356_CAR_SHOPPING_ERRANDS.gpx -rw-rw-r--   1 1019     1019        45374 08 Jun 18:35 wikiloc_35608_356_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_35609_356_CAR_SHOPPING_ERRANDS.gpx -rw-rw-r--   1 1019     1019        47359 08 Jun 18:35 wikiloc_35609_356_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_35610_356_CAR_LEISURE.gpx -rw-rw-r--   1 1019     1019       108377 08 Jun 18:35 wikiloc_35610_356_CAR_LEISURE.gpx
# wikiloc_35611_356_CAR_LEISURE.gpx -rw-rw-r--   1 1019     1019       134733 08 Jun 18:35 wikiloc_35611_356_CAR_LEISURE.gpx
# wikiloc_35612_356_CAR_LEISURE.gpx -rw-rw-r--   1 1019     1019       165828 08 Jun 18:35 wikiloc_35612_356_CAR_LEISURE.gpx
# wikiloc_35613_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        53402 08 Jun 18:35 wikiloc_35613_356_CAR_OTHER.gpx
# wikiloc_35614_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        56992 08 Jun 18:35 wikiloc_35614_356_CAR_OTHER.gpx
# wikiloc_35615_356_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        43237 08 Jun 18:35 wikiloc_35615_356_CAR_EDUCATION.gpx
# wikiloc_35616_356_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019        32586 08 Jun 18:35 wikiloc_35616_356_CAR_EDUCATION.gpx
# wikiloc_35617_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        59583 08 Jun 18:35 wikiloc_35617_356_CAR_OTHER.gpx
# wikiloc_35618_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        50994 08 Jun 18:35 wikiloc_35618_356_CAR_OTHER.gpx
# wikiloc_35619_356_CAR_SHOPPING_ERRANDS.gpx -rw-rw-r--   1 1019     1019        37080 08 Jun 18:35 wikiloc_35619_356_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_35620_356_CAR_SHOPPING_ERRANDS.gpx -rw-rw-r--   1 1019     1019        28830 08 Jun 18:35 wikiloc_35620_356_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_35621_356_CAR_OTHER.gpx -rw-rw-r--   1 1019     1019        77730 08 Jun 18:35 wikiloc_35621_356_CAR_OTHER.gpx
# wikiloc_35622_356_CAR_EDUCATION.gpx -rw-rw-r--   1 1019     1019       107430 08 Jun 18:35 wikiloc_35622_356_CAR_EDUCATION.gpx
# wikiloc_411100_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       246465 12 Jun 22:52 wikiloc_411100_411_WALK_HEALTH.gpx
# wikiloc_411101_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       276575 12 Jun 22:52 wikiloc_411101_411_WALK_HEALTH.gpx
# wikiloc_411102_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019      1511200 12 Jun 22:52 wikiloc_411102_411_WALK_HEALTH.gpx
# wikiloc_411103_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       954160 12 Jun 22:52 wikiloc_411103_411_WALK_HEALTH.gpx
# wikiloc_411104_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       946103 12 Jun 22:52 wikiloc_411104_411_WALK_HEALTH.gpx
# wikiloc_411105_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       913392 12 Jun 22:53 wikiloc_411105_411_WALK_HEALTH.gpx
# wikiloc_411276_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       278274 12 Jun 22:53 wikiloc_411276_411_WALK_HEALTH.gpx
# wikiloc_411277_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       847945 12 Jun 22:53 wikiloc_411277_411_WALK_HEALTH.gpx
# wikiloc_411278_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019      1015429 12 Jun 22:53 wikiloc_411278_411_WALK_HEALTH.gpx
# wikiloc_411279_411_WALK_HEALTH.gpx -rw-rw-r--   1 1019     1019       615528 12 Jun 22:53 wikiloc_411279_411_WALK_HEALTH.gpx
# ...
# wikiloc_411454_411_WALK_HEALTH.gpx
# wikiloc_411455_411_WALK_HEALTH.gpx
# wikiloc_411456_411_WALK_HEALTH.gpx
# wikiloc_411457_411_WALK_HEALTH.gpx
# wikiloc_411458_411_WALK_HEALTH.gpx
# wikiloc_411459_411_WALK_HEALTH.gpx
# wikiloc_411460_411_WALK_HEALTH.gpx
# wikiloc_411461_411_WALK_HEALTH.gpx
# wikiloc_411462_411_WALK_HEALTH.gpx
# wikiloc_411463_411_WALK_HEALTH.gpx
# wikiloc_411464_411_WALK_HEALTH.gpx
# wikiloc_411465_411_WALK_HEALTH.gpx
# wikiloc_411466_411_WALK_HEALTH.gpx
# wikiloc_411467_411_WALK_HEALTH.gpx
# wikiloc_411468_411_WALK_HEALTH.gpx
# wikiloc_411469_411_WALK_HEALTH.gpx
# wikiloc_411470_411_WALK_HEALTH.gpx
# wikiloc_411471_411_WALK_HEALTH.gpx
# wikiloc_411472_411_WALK_HEALTH.gpx
# wikiloc_411473_411_WALK_HEALTH.gpx
# wikiloc_411474_411_WALK_HEALTH.gpx
# wikiloc_411475_411_WALK_HEALTH.gpx
# wikiloc_411476_411_WALK_HEALTH.gpx
# wikiloc_411477_411_WALK_HEALTH.gpx
# wikiloc_411478_411_WALK_HEALTH.gpx
# wikiloc_411479_411_WALK_HEALTH.gpx
# wikiloc_411480_411_WALK_HEALTH.gpx
# wikiloc_411481_411_WALK_HEALTH.gpx
# wikiloc_411482_411_WALK_HEALTH.gpx
# wikiloc_411483_411_WALK_HEALTH.gpx
# wikiloc_411484_411_WALK_HEALTH.gpx
# wikiloc_411485_411_WALK_HEALTH.gpx
# wikiloc_411486_411_WALK_HEALTH.gpx
# wikiloc_411487_411_WALK_HEALTH.gpx
# wikiloc_411488_411_WALK_HEALTH.gpx
# wikiloc_411489_411_WALK_HEALTH.gpx
# wikiloc_41148_411_WALK_HEALTH.gpx
# wikiloc_411490_411_WALK_HEALTH.gpx
# wikiloc_411491_411_WALK_HEALTH.gpx
# wikiloc_411492_411_WALK_HEALTH.gpx
# wikiloc_411493_411_WALK_HEALTH.gpx
# wikiloc_411494_411_WALK_HEALTH.gpx
# wikiloc_411495_411_WALK_HEALTH.gpx
# wikiloc_411496_411_WALK_HEALTH.gpx
# wikiloc_411497_411_WALK_HEALTH.gpx
# wikiloc_411498_411_WALK_HEALTH.gpx
# wikiloc_411499_411_WALK_HEALTH.gpx
# wikiloc_41149_411_WALK_HEALTH.gpx
# wikiloc_4114_411_BIKEELECTRIC_EDUCATION.gpx
# wikiloc_411500_411_WALK_HEALTH.gpx
# wikiloc_411501_411_WALK_HEALTH.gpx
# wikiloc_411502_411_WALK_HEALTH.gpx
# wikiloc_411503_411_WALK_HEALTH.gpx
# wikiloc_411504_411_WALK_HEALTH.gpx
# wikiloc_411505_411_WALK_HEALTH.gpx
# wikiloc_411506_411_WALK_HEALTH.gpx
# wikiloc_411507_411_WALK_HEALTH.gpx
# wikiloc_411508_411_WALK_HEALTH.gpx
# wikiloc_411509_411_WALK_HEALTH.gpx
# wikiloc_41150_411_WALK_HEALTH.gpx
# wikiloc_411510_411_WALK_HEALTH.gpx
# wikiloc_411511_411_WALK_HEALTH.gpx
# wikiloc_411512_411_WALK_HEALTH.gpx
# wikiloc_411513_411_WALK_HEALTH.gpx
# wikiloc_411514_411_WALK_HEALTH.gpx
# wikiloc_411515_411_WALK_HEALTH.gpx
# wikiloc_411516_411_WALK_HEALTH.gpx
# wikiloc_411517_411_WALK_HEALTH.gpx
# wikiloc_411518_411_WALK_HEALTH.gpx
# wikiloc_411519_411_WALK_HEALTH.gpx
# wikiloc_411520_411_WALK_HEALTH.gpx
# wikiloc_411521_411_WALK_HEALTH.gpx
# wikiloc_411522_411_WALK_HEALTH.gpx
# wikiloc_411523_411_WALK_HEALTH.gpx
# wikiloc_411524_411_WALK_HEALTH.gpx
# wikiloc_411525_411_WALK_HEALTH.gpx
# wikiloc_411526_411_WALK_HEALTH.gpx
# wikiloc_411527_411_WALK_HEALTH.gpx
# wikiloc_411528_411_WALK_HEALTH.gpx
# wikiloc_411529_411_WALK_HEALTH.gpx
# wikiloc_411530_411_WALK_HEALTH.gpx
# wikiloc_411531_411_WALK_HEALTH.gpx
# wikiloc_411532_411_WALK_HEALTH.gpx
# wikiloc_411533_411_WALK_HEALTH.gpx
# wikiloc_411534_411_WALK_HEALTH.gpx
# wikiloc_411535_411_WALK_HEALTH.gpx
# wikiloc_411536_411_WALK_HEALTH.gpx
# wikiloc_411537_411_WALK_HEALTH.gpx
# wikiloc_411538_411_WALK_HEALTH.gpx
# wikiloc_411539_411_WALK_HEALTH.gpx
# wikiloc_411540_411_WALK_HEALTH.gpx
# wikiloc_411541_411_WALK_HEALTH.gpx
# wikiloc_411542_411_WALK_HEALTH.gpx
# wikiloc_411543_411_WALK_HEALTH.gpx
# wikiloc_411544_411_WALK_HEALTH.gpx
# wikiloc_411545_411_WALK_HEALTH.gpx
# wikiloc_411546_411_WALK_HEALTH.gpx
# wikiloc_411547_411_WALK_HEALTH.gpx
# wikiloc_411548_411_WALK_HEALTH.gpx
# wikiloc_411549_411_WALK_HEALTH.gpx
# wikiloc_411550_411_WALK_HEALTH.gpx
# wikiloc_411551_411_WALK_HEALTH.gpx
# wikiloc_411552_411_WALK_HEALTH.gpx
# wikiloc_411553_411_WALK_HEALTH.gpx
# wikiloc_411554_411_WALK_HEALTH.gpx
# wikiloc_411555_411_WALK_HEALTH.gpx
# wikiloc_411556_411_WALK_HEALTH.gpx
# wikiloc_411557_411_WALK_HEALTH.gpx
# wikiloc_411558_411_WALK_HEALTH.gpx
# wikiloc_411559_411_WALK_HEALTH.gpx
# wikiloc_411560_411_WALK_HEALTH.gpx
# wikiloc_411561_411_WALK_HEALTH.gpx
# wikiloc_411562_411_WALK_HEALTH.gpx
# wikiloc_411563_411_WALK_HEALTH.gpx
# wikiloc_411564_411_WALK_HEALTH.gpx
# wikiloc_411565_411_WALK_HEALTH.gpx
# wikiloc_411566_411_WALK_HEALTH.gpx
# wikiloc_411567_411_WALK_HEALTH.gpx
# wikiloc_411568_411_WALK_HEALTH.gpx
# wikiloc_411569_411_WALK_HEALTH.gpx
# wikiloc_411570_411_WALK_HEALTH.gpx
# wikiloc_411571_411_WALK_HEALTH.gpx
# wikiloc_411572_411_WALK_HEALTH.gpx
# wikiloc_411573_411_WALK_HEALTH.gpx
# wikiloc_411574_411_WALK_HEALTH.gpx
# wikiloc_411575_411_WALK_HEALTH.gpx
# wikiloc_411576_411_WALK_HEALTH.gpx
# wikiloc_411577_411_WALK_HEALTH.gpx
# wikiloc_411578_411_WALK_HEALTH.gpx
# wikiloc_411579_411_WALK_HEALTH.gpx
# wikiloc_411580_411_WALK_HEALTH.gpx
# wikiloc_411581_411_WALK_HEALTH.gpx
# wikiloc_411582_411_WALK_HEALTH.gpx
# wikiloc_411583_411_WALK_HEALTH.gpx
# wikiloc_411584_411_WALK_HEALTH.gpx
# wikiloc_411585_411_WALK_HEALTH.gpx
# wikiloc_411586_411_WALK_HEALTH.gpx
# wikiloc_411587_411_WALK_HEALTH.gpx
# wikiloc_411588_411_WALK_HEALTH.gpx
# wikiloc_411589_411_WALK_HEALTH.gpx
# wikiloc_411590_411_WALK_HEALTH.gpx
# wikiloc_411591_411_WALK_HEALTH.gpx
# wikiloc_411592_411_WALK_HEALTH.gpx
# wikiloc_411593_411_WALK_HEALTH.gpx
# wikiloc_411594_411_WALK_HEALTH.gpx
# wikiloc_411595_411_WALK_HEALTH.gpx
# wikiloc_411596_411_WALK_HEALTH.gpx
# wikiloc_411597_411_WALK_HEALTH.gpx
# wikiloc_411598_411_WALK_HEALTH.gpx
# wikiloc_411599_411_WALK_HEALTH.gpx
# wikiloc_4115_411_BIKEELECTRIC_LEISURE.gpx
# wikiloc_411600_411_WALK_HEALTH.gpx
# wikiloc_411601_411_WALK_HEALTH.gpx
# wikiloc_411602_411_WALK_HEALTH.gpx
# wikiloc_411603_411_WALK_HEALTH.gpx
# wikiloc_411604_411_WALK_HEALTH.gpx
# wikiloc_411605_411_WALK_HEALTH.gpx
# wikiloc_411606_411_WALK_HEALTH.gpx
# wikiloc_411607_411_WALK_HEALTH.gpx
# wikiloc_411608_411_WALK_HEALTH.gpx
# wikiloc_411609_411_WALK_HEALTH.gpx
# wikiloc_411610_411_WALK_HEALTH.gpx
# wikiloc_411611_411_WALK_HEALTH.gpx
# wikiloc_411612_411_WALK_HEALTH.gpx
# wikiloc_411613_411_WALK_HEALTH.gpx
# wikiloc_411614_411_WALK_HEALTH.gpx
# wikiloc_411615_411_WALK_HEALTH.gpx
# wikiloc_411616_411_WALK_HEALTH.gpx
# wikiloc_411617_411_WALK_HEALTH.gpx
# wikiloc_411618_411_WALK_HEALTH.gpx
# wikiloc_411619_411_WALK_HEALTH.gpx
# wikiloc_411620_411_WALK_HEALTH.gpx
# wikiloc_411621_411_WALK_HEALTH.gpx
# wikiloc_411622_411_WALK_HEALTH.gpx
# wikiloc_411623_411_WALK_HEALTH.gpx
# wikiloc_411624_411_WALK_HEALTH.gpx
# wikiloc_411625_411_WALK_HEALTH.gpx
# wikiloc_411626_411_WALK_HEALTH.gpx
# wikiloc_411627_411_WALK_HEALTH.gpx
# wikiloc_411628_411_WALK_HEALTH.gpx
# wikiloc_411629_411_WALK_HEALTH.gpx
# wikiloc_411630_411_WALK_HEALTH.gpx
# wikiloc_411631_411_WALK_HEALTH.gpx
# wikiloc_411632_411_WALK_HEALTH.gpx
# wikiloc_411633_411_WALK_HEALTH.gpx
# wikiloc_411634_411_WALK_HEALTH.gpx
# wikiloc_411635_411_WALK_HEALTH.gpx
# wikiloc_411636_411_WALK_HEALTH.gpx
# wikiloc_411637_411_WALK_HEALTH.gpx
# wikiloc_411638_411_WALK_HEALTH.gpx
# wikiloc_411639_411_WALK_HEALTH.gpx
# wikiloc_411640_411_WALK_HEALTH.gpx
# wikiloc_411641_411_WALK_HEALTH.gpx
# wikiloc_411642_411_WALK_HEALTH.gpx
# wikiloc_411643_411_WALK_HEALTH.gpx
# wikiloc_411644_411_WALK_HEALTH.gpx
# wikiloc_411645_411_WALK_HEALTH.gpx
# wikiloc_411646_411_WALK_HEALTH.gpx
# wikiloc_411647_411_WALK_HEALTH.gpx
# wikiloc_411648_411_WALK_HEALTH.gpx
# wikiloc_411649_411_WALK_HEALTH.gpx
# wikiloc_411650_411_WALK_HEALTH.gpx
# wikiloc_411651_411_WALK_HEALTH.gpx
# wikiloc_411652_411_WALK_HEALTH.gpx
# wikiloc_411653_411_WALK_HEALTH.gpx
# wikiloc_411654_411_WALK_HEALTH.gpx
# wikiloc_411655_411_WALK_HEALTH.gpx
# wikiloc_411656_411_WALK_HEALTH.gpx
# wikiloc_411657_411_WALK_HEALTH.gpx
# wikiloc_411658_411_WALK_HEALTH.gpx
# wikiloc_411659_411_WALK_HEALTH.gpx
# wikiloc_411660_411_WALK_HEALTH.gpx
# wikiloc_411661_411_WALK_HEALTH.gpx
# wikiloc_411662_411_WALK_HEALTH.gpx
# wikiloc_411663_411_WALK_HEALTH.gpx
# wikiloc_411664_411_WALK_HEALTH.gpx
# wikiloc_411665_411_WALK_HEALTH.gpx
# wikiloc_411666_411_WALK_HEALTH.gpx
# wikiloc_411667_411_WALK_HEALTH.gpx
# wikiloc_411668_411_WALK_HEALTH.gpx
# wikiloc_411669_411_WALK_HEALTH.gpx
# wikiloc_411670_411_WALK_HEALTH.gpx
# wikiloc_411671_411_WALK_HEALTH.gpx
# wikiloc_411672_411_WALK_HEALTH.gpx
# wikiloc_411673_411_WALK_HEALTH.gpx
# wikiloc_411674_411_WALK_HEALTH.gpx
# wikiloc_411675_411_WALK_HEALTH.gpx
# wikiloc_411676_411_WALK_HEALTH.gpx
# wikiloc_411677_411_WALK_HEALTH.gpx
# wikiloc_411678_411_WALK_HEALTH.gpx
# wikiloc_411679_411_WALK_HEALTH.gpx
# wikiloc_411680_411_WALK_HEALTH.gpx
# wikiloc_411681_411_WALK_HEALTH.gpx
# wikiloc_411682_411_WALK_HEALTH.gpx
# wikiloc_411683_411_WALK_HEALTH.gpx
# wikiloc_411684_411_WALK_HEALTH.gpx
# wikiloc_411685_411_WALK_HEALTH.gpx
# wikiloc_411686_411_WALK_HEALTH.gpx
# wikiloc_411687_411_WALK_HEALTH.gpx
# wikiloc_411688_411_WALK_HEALTH.gpx
# wikiloc_411689_411_WALK_HEALTH.gpx
# wikiloc_411690_411_WALK_HEALTH.gpx
# wikiloc_411691_411_WALK_HEALTH.gpx
# wikiloc_411692_411_WALK_HEALTH.gpx
# wikiloc_411693_411_WALK_HEALTH.gpx
# wikiloc_411694_411_WALK_HEALTH.gpx
# wikiloc_411695_411_WALK_HEALTH.gpx
# wikiloc_411696_411_WALK_HEALTH.gpx
# wikiloc_411697_411_WALK_HEALTH.gpx
# wikiloc_411698_411_WALK_HEALTH.gpx
# wikiloc_411699_411_WALK_HEALTH.gpx
# wikiloc_4116_411_BIKEELECTRIC_HEALTH.gpx
# wikiloc_411700_411_WALK_HEALTH.gpx
# wikiloc_411701_411_WALK_HEALTH.gpx
# wikiloc_411702_411_WALK_HEALTH.gpx
# wikiloc_411703_411_WALK_HEALTH.gpx
# wikiloc_411704_411_WALK_HEALTH.gpx
# wikiloc_411705_411_WALK_HEALTH.gpx
# wikiloc_411706_411_WALK_HEALTH.gpx
# wikiloc_411707_411_WALK_HEALTH.gpx
# wikiloc_411708_411_WALK_HEALTH.gpx
# wikiloc_411709_411_WALK_HEALTH.gpx
# wikiloc_411710_411_WALK_HEALTH.gpx
# wikiloc_411711_411_WALK_HEALTH.gpx
# wikiloc_411712_411_WALK_HEALTH.gpx
# wikiloc_411713_411_WALK_HEALTH.gpx
# wikiloc_411714_411_WALK_HEALTH.gpx
# wikiloc_411715_411_WALK_HEALTH.gpx
# wikiloc_411716_411_WALK_HEALTH.gpx
# wikiloc_411717_411_WALK_HEALTH.gpx
# wikiloc_411718_411_WALK_HEALTH.gpx
# wikiloc_411719_411_WALK_HEALTH.gpx
# wikiloc_411720_411_WALK_HEALTH.gpx
# wikiloc_411721_411_WALK_HEALTH.gpx
# wikiloc_411722_411_WALK_HEALTH.gpx
# wikiloc_411723_411_WALK_HEALTH.gpx
# wikiloc_411724_411_WALK_HEALTH.gpx
# wikiloc_411725_411_WALK_HEALTH.gpx
# wikiloc_411726_411_WALK_HEALTH.gpx
# wikiloc_411727_411_WALK_HEALTH.gpx
# wikiloc_411728_411_WALK_HEALTH.gpx
# wikiloc_411729_411_WALK_HEALTH.gpx
# wikiloc_411730_411_WALK_HEALTH.gpx
# wikiloc_411731_411_WALK_HEALTH.gpx
# wikiloc_411732_411_WALK_HEALTH.gpx
# wikiloc_411733_411_WALK_HEALTH.gpx
# wikiloc_411734_411_WALK_HEALTH.gpx
# wikiloc_411735_411_WALK_HEALTH.gpx
# wikiloc_411736_411_WALK_HEALTH.gpx
# wikiloc_411737_411_WALK_HEALTH.gpx
# wikiloc_411738_411_WALK_HEALTH.gpx
# wikiloc_411739_411_WALK_HEALTH.gpx
# wikiloc_411740_411_WALK_HEALTH.gpx
# wikiloc_411741_411_WALK_HEALTH.gpx
# wikiloc_411742_411_WALK_HEALTH.gpx
# wikiloc_411743_411_WALK_HEALTH.gpx
# wikiloc_411744_411_WALK_HEALTH.gpx
# wikiloc_411745_411_WALK_HEALTH.gpx
# wikiloc_411746_411_WALK_HEALTH.gpx
# wikiloc_411747_411_WALK_HEALTH.gpx
# wikiloc_411748_411_WALK_HEALTH.gpx
# wikiloc_411749_411_WALK_HEALTH.gpx
# wikiloc_411750_411_WALK_HEALTH.gpx
# wikiloc_411751_411_WALK_HEALTH.gpx
# wikiloc_411752_411_WALK_HEALTH.gpx
# wikiloc_411753_411_WALK_HEALTH.gpx
# wikiloc_411754_411_WALK_HEALTH.gpx
# wikiloc_411755_411_WALK_HEALTH.gpx
# wikiloc_411756_411_WALK_HEALTH.gpx
# wikiloc_411757_411_WALK_HEALTH.gpx
# wikiloc_411758_411_WALK_HEALTH.gpx
# wikiloc_411759_411_WALK_HEALTH.gpx
# wikiloc_411760_411_WALK_HEALTH.gpx
# wikiloc_411761_411_WALK_HEALTH.gpx
# wikiloc_411762_411_WALK_HEALTH.gpx
# wikiloc_411763_411_WALK_HEALTH.gpx
# wikiloc_411764_411_WALK_HEALTH.gpx
# wikiloc_411765_411_WALK_HEALTH.gpx
# wikiloc_411766_411_WALK_HEALTH.gpx
# wikiloc_411767_411_WALK_HEALTH.gpx
# wikiloc_411768_411_WALK_HEALTH.gpx
# wikiloc_411769_411_WALK_HEALTH.gpx
# wikiloc_411770_411_WALK_HEALTH.gpx
# wikiloc_411771_411_WALK_HEALTH.gpx
# wikiloc_411772_411_WALK_HEALTH.gpx
# wikiloc_411773_411_WALK_HEALTH.gpx
# wikiloc_411774_411_WALK_HEALTH.gpx
# wikiloc_411775_411_WALK_HEALTH.gpx
# wikiloc_411776_411_WALK_HEALTH.gpx
# wikiloc_411777_411_WALK_HEALTH.gpx
# wikiloc_411778_411_WALK_HEALTH.gpx
# wikiloc_411779_411_WALK_HEALTH.gpx
# wikiloc_411780_411_WALK_HEALTH.gpx
# wikiloc_411781_411_WALK_HEALTH.gpx
# wikiloc_411782_411_WALK_HEALTH.gpx
# wikiloc_411783_411_WALK_HEALTH.gpx
# wikiloc_411784_411_WALK_HEALTH.gpx
# wikiloc_411785_411_WALK_HEALTH.gpx
# wikiloc_411786_411_WALK_HEALTH.gpx
# wikiloc_411787_411_WALK_HEALTH.gpx
# wikiloc_411788_411_WALK_HEALTH.gpx
# wikiloc_411789_411_WALK_HEALTH.gpx
# wikiloc_411790_411_WALK_HEALTH.gpx
# wikiloc_411791_411_WALK_HEALTH.gpx
# wikiloc_411792_411_WALK_HEALTH.gpx
# wikiloc_411793_411_WALK_HEALTH.gpx
# wikiloc_411794_411_WALK_HEALTH.gpx
# wikiloc_411795_411_WALK_HEALTH.gpx
# wikiloc_411796_411_WALK_HEALTH.gpx
# wikiloc_411797_411_WALK_HEALTH.gpx
# wikiloc_411798_411_WALK_HEALTH.gpx
# wikiloc_411799_411_WALK_HEALTH.gpx
# wikiloc_4117_411_BIKEELECTRIC_EDUCATION.gpx
# wikiloc_411800_411_WALK_HEALTH.gpx
# wikiloc_411801_411_WALK_HEALTH.gpx
# wikiloc_411802_411_WALK_HEALTH.gpx
# wikiloc_411803_411_WALK_HEALTH.gpx
# wikiloc_411804_411_WALK_HEALTH.gpx
# wikiloc_411805_411_WALK_HEALTH.gpx
# wikiloc_411806_411_WALK_HEALTH.gpx
# wikiloc_411807_411_WALK_HEALTH.gpx
# wikiloc_411808_411_WALK_HEALTH.gpx
# wikiloc_411809_411_WALK_HEALTH.gpx
# wikiloc_411810_411_WALK_HEALTH.gpx
# wikiloc_411811_411_WALK_HEALTH.gpx
# wikiloc_411812_411_WALK_HEALTH.gpx
# wikiloc_411813_411_WALK_HEALTH.gpx
# wikiloc_411814_411_WALK_HEALTH.gpx
# wikiloc_411815_411_WALK_HEALTH.gpx
# wikiloc_411816_411_WALK_HEALTH.gpx
# wikiloc_411817_411_WALK_HEALTH.gpx
# wikiloc_411818_411_WALK_HEALTH.gpx
# wikiloc_411819_411_WALK_HEALTH.gpx
# wikiloc_411820_411_WALK_HEALTH.gpx
# wikiloc_411821_411_WALK_HEALTH.gpx
# wikiloc_411822_411_WALK_HEALTH.gpx
# wikiloc_411823_411_WALK_HEALTH.gpx
# wikiloc_411824_411_WALK_HEALTH.gpx
# wikiloc_411825_411_WALK_HEALTH.gpx
# wikiloc_411826_411_WALK_HEALTH.gpx
# wikiloc_411827_411_WALK_HEALTH.gpx
# wikiloc_411828_411_WALK_HEALTH.gpx
# wikiloc_411829_411_WALK_HEALTH.gpx
# wikiloc_411830_411_WALK_HEALTH.gpx
# wikiloc_411831_411_WALK_HEALTH.gpx
# wikiloc_411832_411_WALK_HEALTH.gpx
# wikiloc_411833_411_WALK_HEALTH.gpx
# wikiloc_411834_411_WALK_HEALTH.gpx
# wikiloc_411835_411_WALK_HEALTH.gpx
# wikiloc_411836_411_WALK_HEALTH.gpx
# wikiloc_411837_411_WALK_HEALTH.gpx
# wikiloc_411838_411_WALK_HEALTH.gpx
# wikiloc_411839_411_WALK_HEALTH.gpx
# wikiloc_411840_411_WALK_HEALTH.gpx
# wikiloc_411841_411_WALK_HEALTH.gpx
# wikiloc_411842_411_WALK_HEALTH.gpx
# wikiloc_411843_411_WALK_HEALTH.gpx
# wikiloc_411844_411_WALK_HEALTH.gpx
# wikiloc_411845_411_WALK_HEALTH.gpx
# wikiloc_411846_411_WALK_HEALTH.gpx
# wikiloc_411847_411_WALK_HEALTH.gpx
# wikiloc_411848_411_WALK_HEALTH.gpx
# wikiloc_411849_411_WALK_HEALTH.gpx
# wikiloc_411850_411_WALK_HEALTH.gpx
# wikiloc_411851_411_WALK_HEALTH.gpx
# wikiloc_411852_411_WALK_HEALTH.gpx
# wikiloc_411853_411_WALK_HEALTH.gpx
# wikiloc_411854_411_WALK_HEALTH.gpx
# wikiloc_411855_411_WALK_HEALTH.gpx
# wikiloc_411856_411_WALK_HEALTH.gpx
# wikiloc_411857_411_WALK_HEALTH.gpx
# wikiloc_411858_411_WALK_HEALTH.gpx
# wikiloc_411859_411_WALK_HEALTH.gpx
# wikiloc_411860_411_WALK_HEALTH.gpx
# wikiloc_411861_411_WALK_HEALTH.gpx
# wikiloc_411862_411_WALK_HEALTH.gpx
# wikiloc_411863_411_WALK_HEALTH.gpx
# wikiloc_411864_411_WALK_HEALTH.gpx
# wikiloc_411865_411_WALK_HEALTH.gpx
# wikiloc_411866_411_WALK_HEALTH.gpx
# wikiloc_411867_411_WALK_HEALTH.gpx
# wikiloc_411868_411_WALK_HEALTH.gpx
# wikiloc_411869_411_WALK_HEALTH.gpx
# wikiloc_411870_411_WALK_HEALTH.gpx
# wikiloc_411871_411_WALK_HEALTH.gpx
# wikiloc_411872_411_WALK_HEALTH.gpx
# wikiloc_411873_411_WALK_HEALTH.gpx
# wikiloc_411874_411_WALK_HEALTH.gpx
# wikiloc_411875_411_WALK_HEALTH.gpx
# wikiloc_411876_411_WALK_HEALTH.gpx
# wikiloc_4118_411_BIKEELECTRIC_EDUCATION.gpx
# wikiloc_4119_411_BIKEELECTRIC_LEISURE.gpx
# wikiloc_58101_581_CAR_HEALTH.gpx
# wikiloc_58102_581_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_58103_581_CAR_OTHER.gpx
# wikiloc_58104_581_CAR_OTHER.gpx
# wikiloc_70800_708_CAR_EDUCATION.gpx
# wikiloc_70801_708_CAR_EDUCATION.gpx
# wikiloc_70802_708_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_70803_708_CAR_LEISURE.gpx
# wikiloc_70804_708_WALK_LEISURE.gpx
# wikiloc_70805_708_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_70806_708_CAR_OTHER.gpx
# wikiloc_70807_708_CAR_OTHER.gpx
# wikiloc_70808_708_CAR_SHOPPING_ERRANDS.gpx
# wikiloc_70809_708_CAR_EDUCATION.gpx
# wikiloc_70810_708_CAR_OTHER.gpx
# wikiloc_84001_840_BIKE_HEALTH.gpx
# wikiloc_84002_840_BIKE_HEALTH.gpx
# wikiloc_84003_840_BIKE_HEALTH.gpx
# wikiloc_84004_840_BIKE_HEALTH.gpx
# wikiloc_84005_840_BIKE_HEALTH.gpx
# wikiloc_84006_840_BIKE_HEALTH.gpx
# wikiloc_84007_840_BIKE_HEALTH.gpx
# wikiloc_84008_840_BIKE_HEALTH.gpx

# %% [markdown]
# #### Import FourSquare data

# %%
# Function to create the pois table if it doesn't exist

def create_pois_table():
    try:
        cursor.execute('''
            CREATE TABLE IF NOT EXISTS pois (
            id  SERIAL PRIMARY KEY,
                venueID VARCHAR(255),
                latitude FLOAT,
                longitude FLOAT,
                venueCategory VARCHAR(255),
                countryCode VARCHAR(255)
            )
        ''')

        conn.commit()
        print("Table created successfully")
    except Exception as e:
        print("Error occurred during query execution:", e)

# %%
create_pois_table()

# %%
# File path of the Foursquare POI data
file_name = r'foursquare\dataset_TIST2015_POIs.txt'


def import_foursquare_pois():
    with open(file_name, 'r') as file:
        for line in file:
            row = line.strip().split('	')  # Update the split delimiter to match the blank space
            venueID = row[0]
            latitude = row[1]
            longitude = row[2]
            venueCategory = row[3]
            countryCode = row[4]

            if countryCode == 'PT':  # Add this condition to check if the address is 'PT'
                cursor.execute(
                    "INSERT INTO pois (venueID, latitude, longitude, venueCategory,countryCode) VALUES (%s, %s, %s, %s,%s)",
                    (venueID, latitude, longitude, venueCategory, countryCode)
                )

        conn.commit()

# %%
import_foursquare_pois()

# %% [markdown]
# #### Import DGT (Coimbra streets) data

# %%
env_dict = os.environ.copy()
print(env_dict['PATH'])
# Out:
# C:\ProgramData\Anaconda3;C:\ProgramData\Anaconda3\Library\mingw-w64\bin;C:\ProgramData\Anaconda3\Library\usr\bin;C:\ProgramData\Anaconda3\Library\bin;C:\ProgramData\Anaconda3\Scripts;C:\ProgramData\Anaconda3\bin;C:\ProgramData\Anaconda3\condabin;C:\Program Files\Common Files\Oracle\Java\javapath;C:\Program Files (x86)\Intel\iCLS Client;C:\Program Files\Intel\iCLS Client;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0;C:\Program Files (x86)\Intel\Intel(R) Management Engine Components\DAL;C:\Program Files\Intel\Intel(R) Management Engine Components\DAL;C:\Program Files (x86)\Intel\Intel(R) Management Engine Components\IPT;C:\Program Files\Intel\Intel(R) Management Engine Components\IPT;C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program Files\Intel\WiFi\bin;C:\Program Files\Common Files\Intel\WirelessCommon;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0;C:\WINDOWS\System32\OpenSSH;C:\Program Files\Git\cmd;C:\Tools\apache-maven-3.9.1-bin\apache-maven-3.9.1\bin;C:\Program Files\Docker\Docker\resources\bin;C:\Program Files\PostgreSQL\15\bin;C:\Users\isabe\AppData\Local\Programs\Python\Python311\Scripts;C:\Users\isabe\AppData\Local\Programs\Python\Python311;C:\Users\isabe\AppData\Local\Microsoft\WindowsApps;C:\Tools\mongosh-1.8.0-win32-x64\bin;C:\Tools\apache-maven-3.5.4-bin\apache-maven-3.5.4\bin;C:\Program Files\JetBrains\DataSpell 2023.1.2\bin;.;C:\Program Files\PostgreSQL\15\bin;.;C:\ProgramData\Anaconda3\Library\Bin

# %%
#using the command sh2psgql with the following options
# -s SRID -> coordinate reference system id
# -c -> create the table and populate with data
# -I -> creates a spatial index after loading the data
# -S -> simple geometry (instead of MULTI)
# -e -> each insert is executed right after its indication (no batch mode)
#Assuming the following programs (shp2pgsql and psql) are available at PostgreSQL/X/bin in the PATH or specific locations

#creating the SQL output to be imported later into PostgreSQL database
#please verify if environment PATH variable contains PostgreSQL bin folder
env_dict = os.environ.copy()
print(env_dict['PATH'])

completed1 = subprocess.run(['shp2pgsql', '-s', '4326', '-c', '-I', '-S', '-e', 'portugal/roads.shp', 'public.roads'] ,capture_output=True, check=True, env=env_dict)
print('Errors:')
print(completed1.stderr.decode('utf-8'))
print('___________________________\nOutput:')
print(completed1.stdout.decode('utf-8')[:800])
cursor.execute(completed1.stdout.decode('utf-8'))

# %%
completed1 = subprocess.run(['shp2pgsql', '-s', '4326', '-c', '-I', '-S', '-e', 'portugal/landuse.shp', 'public.landuse'] ,capture_output=True, check=True, env=env_dict)
print('Errors:')
print(completed1.stderr.decode('utf-8'))
print('___________________________\nOutput:')
print(completed1.stdout.decode('utf-8')[:800])
cursor.execute(completed1.stdout.decode('utf-8'))

# %%
completed1 = subprocess.run(['shp2pgsql', '-s', '4326', '-c', '-I', '-e', 'canada/trajets_mtl_trajet_2017.shp', 'public.canada'] ,capture_output=True, check=True, env=env_dict)
print('Errors:')
print(completed1.stderr.decode('utf-8'))
print('___________________________\nOutput:')
print(completed1.stdout.decode('utf-8')[:800])
cursor.execute(completed1.stdout.decode('utf-8'))

# %%
completed1 = subprocess.run(['shp2pgsql', '-s', '4326', '-c', '-I', '-e', 'portugal/carta_continental/Cont_Freg_CAOP2022.shp', 'public.freguesias'] ,capture_output=True, check=True, env=env_dict)
print('Errors:')
print(completed1.stderr.decode('utf-8'))
print('___________________________\nOutput:')
print(completed1.stdout.decode('utf-8')[:800])
cursor.execute(completed1.stdout.decode('utf-8'))
# Out:
# Errors:
# Field area_ha is an FTDouble with width 19 and precision 11
# Shapefile type: Polygon
# Postgis type: MULTIPOLYGON[2]
#
# ___________________________
# Output:
# SET CLIENT_ENCODING TO UTF8;
# SET STANDARD_CONFORMING_STRINGS TO ON;
# CREATE TABLE "public"."freguesias" (gid serial,
# "dicofre" varchar(6),
# "freguesia" varchar(150),
# "concelho" varchar(50),
# "distrito" varchar(50),
# "area_ha" numeric,
# "des_simpli" varchar(150));
# ALTER TABLE "public"."freguesias" ADD PRIMARY KEY (gid);
# SELECT AddGeometryColumn('public','freguesias','geom','4326','MULTIPOLYGON',2);
# INSERT INTO "public"."freguesias" ("dicofre","freguesia","concelho","distrito","area_ha","des_simpli",geom) VALUES ('010103','Aguada de Cima','Águeda','Aveiro','2.83931000000e+03','Aguada de Cima','0106000020E6100000010000000103000000010000003B0100000032E6AE49EED5C080627FD91CBCF7400004E78CF4E5D5C080643BDFF0B9F740005C2041EDADD5C000DE0209E8A8F740004FAF94E18ED5C080D85F762B9DF74000713D0A9762D5C
